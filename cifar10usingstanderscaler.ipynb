# %% [markdown]
# <a href="https://colab.research.google.com/github/shannigrahiayan36-dot/cifar10/blob/main/cifar10usingstanderscaler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Image Classification with Deep Neural Networks
#
# This notebook demonstrates a deep learning approach to classifying images from the CIFAR-10 dataset using TensorFlow and Keras. The project covers data preprocessing, scaling, and training a deep MLP with modern optimization techniques.

# %%
import numpy, pandas, matplotlib

# %% [markdown]
# ## 1. Model Architecture
#
# We define a Sequential model with 20 hidden layers, each containing 100 neurons. We use the **ELU** activation function and **He Normal** initialization, which are well-suited for deep networks to prevent vanishing/exploding gradients.

# %%
from tensorflow import keras

model = keras.models.Sequential([
keras.layers.Flatten(input_shape=[32,32,3]),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# ## 2. Data Loading and Preprocessing
#
# First, we load the CIFAR-10 dataset. To ensure the model converges effectively, we apply **StandardScaler** from Scikit-Learn. Since the scaler expects 2D input, we flatten the images, scale them, and then reshape them back to their original 32x32x3 dimensions.

# %%
Data=keras.datasets.cifar10.load_data()

# %%
(X_train_full, y_train_full), (X_test, y_test) = Data

print(f"Train images shape: {X_train_full.shape}")
print(f"Train labels shape: {y_train_full.shape}")

from sklearn.preprocessing import StandardScaler

# Store original shapes for reshaping later
original_train_shape = X_train_full.shape
original_test_shape = X_test.shape

# Reshape X_train_full and X_test to 2D for StandardScaler
X_train_full_reshaped = X_train_full.reshape(original_train_shape[0], -1)
X_test_reshaped = X_test.reshape(original_test_shape[0], -1)

# Initialize StandardScaler
scaler = StandardScaler()

# Fit on training data and transform both training and test data
X_train_full_scaled = scaler.fit_transform(X_train_full_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped)

# Reshape back to original 4D shapes
X_train_full = X_train_full_scaled.reshape(original_train_shape)
X_test = X_test_scaled.reshape(original_test_shape)

print(f"Scaled X_train_full shape: {X_train_full.shape}")
print(f"Scaled X_test shape: {X_test.shape}")
# Out:
# Train images shape: (50000, 32, 32, 3)
# Train labels shape: (50000, 1)
# Scaled X_train_full shape: (50000, 32, 32, 3)
# Scaled X_test shape: (10000, 32, 32, 3)

# %%
# Creating validation set
# Pixel values are already scaled by StandardScaler in the previous step.
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

print(f"Validation set shape: {X_valid.shape}")
print(f"New training set shape: {X_train.shape}")
# Out:
# Validation set shape: (5000, 32, 32, 3)
# New training set shape: (45000, 32, 32, 3)

# %% [markdown]
# ### Data Visualization
#
# It is important to verify the data. Here we visualize a sample image from the training set. Note that since the data is standardized (mean 0, variance 1), the pixel values may appear clipped in standard viewers.

# %%
import matplotlib.pyplot as plt

#loding a image
first_image = X_train[0]
first_label = y_train[0]

# Display the image
plt.imshow(first_image)
plt.title(f"Image at index {0}, Label: {first_label[0]}")
plt.axis('off') # Hide axes for a cleaner look
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.177363363033382..1.0635870794009066].

# %% [markdown]
# ## 3. Optimization and Training
#
# We use the **Nadam** optimizer for faster convergence and implement **Early Stopping**. Early stopping monitors the validation loss and restores the best weights if the model stops improving, preventing overfitting.

# %%
optimizer = keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
import tensorflow as tf

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    mode='min'
)

# %%
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[early_stopping], epochs=100)
# Out:
# Epoch 1/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 26s 13ms/step - accuracy: 0.3230 - loss: 1.8888 - val_accuracy: 0.3354 - val_loss: 1.7911
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.3996 - loss: 1.6807 - val_accuracy: 0.3904 - val_loss: 1.7193
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.4364 - loss: 1.5926 - val_accuracy: 0.4088 - val_loss: 1.6758
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.4576 - loss: 1.5296 - val_accuracy: 0.4406 - val_loss: 1.5939
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4765 - loss: 1.4843 - val_accuracy: 0.4608 - val_loss: 1.5245
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4939 - loss: 1.4371 - val_accuracy: 0.4614 - val_loss: 1.5621
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.5005 - loss: 1.4213 - val_accuracy: 0.4678 - val_loss: 1.5274
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.5223 - loss: 1.3570 - val_accuracy: 0.4794 - val_loss: 1.5052
# Epoch 9/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.5340 - loss: 1.3232 - val_accuracy: 0.4854 - val_loss: 1.4969
# Epoch 10/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.5458 - loss: 1.2999 - val_accuracy: 0.4950 - val_loss: 1.4763
# Epoch 11/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.5517 - loss: 1.2741 - val_accuracy: 0.4986 - val_loss: 1.4806
# Epoch 12/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.5228 - loss: 1.4651 - val_accuracy: 0.4762 - val_loss: 1.5279
# Epoch 13/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.5476 - loss: 1.2766 - val_accuracy: 0.4918 - val_loss: 1.5011
# Epoch 14/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.5682 - loss: 1.2256 - val_accuracy: 0.4946 - val_loss: 1.4748
# Epoch 15/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5825 - loss: 1.1916 - val_accuracy: 0.5030 - val_loss: 1.4564
# Epoch 16/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5910 - loss: 1.1666 - val_accuracy: 0.5016 - val_loss: 1.4572
# Epoch 17/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.5967 - loss: 1.1480 - val_accuracy: 0.5074 - val_loss: 1.4979
# Epoch 18/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.6028 - loss: 1.1376 - val_accuracy: 0.4926 - val_loss: 1.5265
# Epoch 19/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.6088 - loss: 1.1190 - val_accuracy: 0.5116 - val_loss: 1.4999
# Epoch 20/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.6119 - loss: 1.1113 - val_accuracy: 0.4990 - val_loss: 1.5259
# Epoch 21/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6185 - loss: 1.0955 - val_accuracy: 0.4920 - val_loss: 1.5088
# Epoch 22/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.6188 - loss: 1.0917 - val_accuracy: 0.5094 - val_loss: 1.5311
# Epoch 23/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.6296 - loss: 1.0647 - val_accuracy: 0.5016 - val_loss: 1.5235
# Epoch 24/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.6339 - loss: 1.0629 - val_accuracy: 0.5098 - val_loss: 1.5267
# Epoch 25/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.6420 - loss: 1.0304 - val_accuracy: 0.5024 - val_loss: 1.5812

# %% [markdown]
# ## 4. Performance Evaluation
#
# Finally, we plot the training and validation accuracy and loss curves to analyze the model's learning behavior over time.

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()
plt.show()

# %%
D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_983/3632740253.py in <cell line: 0>()
# ----> 1 D
#
# NameError: name 'D' is not defined
