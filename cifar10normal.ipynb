# %% [markdown]
# <a href="https://colab.research.google.com/github/shannigrahiayan36-dot/cifar10/blob/main/cifar10normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Image Classification with Deep Neural Networks
#
# This notebook demonstrates a deep learning approach to classifying images from the CIFAR-10 dataset using TensorFlow and Keras. The project covers data preprocessing, scaling, and training a deep MLP with modern optimization techniques.

# %%
import numpy, pandas, matplotlib

# %% [markdown]
# ## 1. Model Architecture
#
# We define a Sequential model with 20 hidden layers, each containing 100 neurons. We use the **ELU** activation function and **He Normal** initialization, which are well-suited for deep networks to prevent vanishing/exploding gradients.

# %%
from tensorflow import keras

model = keras.models.Sequential([
keras.layers.Flatten(input_shape=[32,32,3]),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(100, activation="elu", kernel_initializer="he_normal"),
keras.layers.Dense(10, activation="softmax")
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## 2. Data Loading and Preprocessing
#
# First, we load the CIFAR-10 dataset. To ensure the model converges effectively, we normalize the pixel values to a range between 0 and 1 by dividing by 255.

# %%
Data=keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
(X_train_full, y_train_full), (X_test, y_test) = Data

print(f"Original train images shape: {X_train_full.shape}")

# Normalize pixel values to range [0, 1]
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0

print(f"Normalized X_train_full shape: {X_train_full.shape}")
print(f"Normalized X_test shape: {X_test.shape}")
# Out:
# Original train images shape: (50000, 32, 32, 3)
# Normalized X_train_full shape: (50000, 32, 32, 3)
# Normalized X_test shape: (10000, 32, 32, 3)

# %%
# Creating validation set
# Pixel values are normalized [0, 1] in the previous step.
X_valid, X_train = X_train_full[:5000], X_train_full[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

print(f"Validation set shape: {X_valid.shape}")
print(f"New training set shape: {X_train.shape}")
# Out:
# Validation set shape: (5000, 32, 32, 3)
# New training set shape: (45000, 32, 32, 3)

# %% [markdown]
# ### Data Visualization
#
# It is important to verify the data. Here we visualize a sample image from the training set. Note that since the data is standardized (mean 0, variance 1), the pixel values may appear clipped in standard viewers.

# %%
import matplotlib.pyplot as plt

#loding a image
first_image = X_train[0]
first_label = y_train[0]

# Display the image
plt.imshow(first_image)
plt.title(f"Image at index {0}, Label: {first_label[0]}")
plt.axis('off') # Hide axes for a cleaner look
plt.show()

# %% [markdown]
# ## 3. Optimization and Training
#
# We use the **Nadam** optimizer for faster convergence and implement **Early Stopping**. Early stopping monitors the validation loss and restores the best weights if the model stops improving, preventing overfitting.

# %%
optimizer = keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
import tensorflow as tf

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    mode='min'
)

# %%
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[early_stopping], epochs=100)
# Out:
# Epoch 1/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.2718 - loss: 2.0097 - val_accuracy: 0.3086 - val_loss: 1.9021
# Epoch 2/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.3405 - loss: 1.8140 - val_accuracy: 0.3326 - val_loss: 1.8625
# Epoch 3/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.3642 - loss: 1.7563 - val_accuracy: 0.3720 - val_loss: 1.7899
# Epoch 4/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.3884 - loss: 1.7094 - val_accuracy: 0.3582 - val_loss: 1.7685
# Epoch 5/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - accuracy: 0.4031 - loss: 1.6786 - val_accuracy: 0.3804 - val_loss: 1.7360
# Epoch 6/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.4122 - loss: 1.6435 - val_accuracy: 0.3978 - val_loss: 1.7566
# Epoch 7/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2995 - loss: 1.9547 - val_accuracy: 0.1856 - val_loss: 2.1259
# Epoch 8/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0
100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.4713 - loss: 1.4666 - val_accuracy: 0.4500 - val_loss: 1.5405
# Epoch 41/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.4808 - loss: 1.4475 - val_accuracy: 0.4516 - val_loss: 1.5669
# Epoch 42/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.4810 - loss: 1.4400 - val_accuracy: 0.4558 - val_loss: 1.5143
# Epoch 43/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4875 - loss: 1.4302 - val_accuracy: 0.4506 - val_loss: 1.5534
# Epoch 44/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4946 - loss: 1.4150 - val_accuracy: 0.4506 - val_loss: 1.5173
# Epoch 45/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.4949 - loss: 1.4073 - val_accuracy: 0.4696 - val_loss: 1.4964
# Epoch 46/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.4505 - loss: 2.0757 - val_accuracy: 0.3946 - val_loss: 1.6670
# Epoch 47/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.4438 - loss: 1.5315 - val_accuracy: 0.4386 - val_loss: 1.5586
# Epoch 48/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4707 - loss: 1.4639 - val_accuracy: 0.4474 - val_loss: 1.5437
# Epoch 49/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.4842 - loss: 1.4376 - val_accuracy: 0.4462 - val_loss: 1.5634
# Epoch 50/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.4931 - loss: 1.4155 - val_accuracy: 0.4584 - val_loss: 1.5354
# Epoch 51/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4949 - loss: 1.4005 - val_accuracy: 0.4684 - val_loss: 1.4986
# Epoch 52/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5032 - loss: 1.3914 - val_accuracy: 0.4668 - val_loss: 1.5087
# Epoch 53/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.5073 - loss: 1.3771 - val_accuracy: 0.4718 - val_loss: 1.4892
# Epoch 54/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5088 - loss: 1.3742 - val_accuracy: 0.4726 - val_loss: 1.5032
# Epoch 55/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.5171 - loss: 1.3516 - val_accuracy: 0.4684 - val_loss: 1.5130
# Epoch 56/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.5161 - loss: 1.3572 - val_accuracy: 0.4800 - val_loss: 1.4851
# Epoch 57/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5268 - loss: 1.3281 - val_accuracy: 0.4728 - val_loss: 1.5153
# Epoch 58/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.5305 - loss: 1.3159 - val_accuracy: 0.4622 - val_loss: 1.5567
# Epoch 59/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5350 - loss: 1.3063 - val_accuracy: 0.4666 - val_loss: 1.5275
# Epoch 60/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.5354 - loss: 1.2962 - val_accuracy: 0.4888 - val_loss: 1.4573
# Epoch 61/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4424 - loss: 72.2719 - val_accuracy: 0.4276 - val_loss: 1.6251
# Epoch 62/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.4557 - loss: 1.5171 - val_accuracy: 0.4462 - val_loss: 1.5508
# Epoch 63/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4751 - loss: 1.4590 - val_accuracy: 0.4588 - val_loss: 1.5344
# Epoch 64/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.4899 - loss: 1.4304 - val_accuracy: 0.4538 - val_loss: 1.5430
# Epoch 65/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.4981 - loss: 1.4071 - val_accuracy: 0.4554 - val_loss: 1.5698
# Epoch 66/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.5024 - loss: 1.3895 - val_accuracy: 0.4610 - val_loss: 1.5327
# Epoch 67/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.5078 - loss: 1.3723 - val_accuracy: 0.4692 - val_loss: 1.4973
# Epoch 68/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5102 - loss: 1.3768 - val_accuracy: 0.4792 - val_loss: 1.5161
# Epoch 69/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.5148 - loss: 1.3495 - val_accuracy: 0.4658 - val_loss: 1.5454
# Epoch 70/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5216 - loss: 1.3410 - val_accuracy: 0.4680 - val_loss: 1.5085

# %% [markdown]
# ## 4. Performance Evaluation
#
# Finally, we plot the training and validation accuracy and loss curves to analyze the model's learning behavior over time.

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()
plt.show()
